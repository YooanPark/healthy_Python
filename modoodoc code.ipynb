},{"gu":"\uc1a1\ud30c\uad6c","dong":"\uc7a0\uc2e47\ub3d9","household":"3,475","pop_total_male":"4,693","pop_total_female":"5,395","over_65":"2,059"},{"gu":"\uc1a1\ud30c\uad6c","dong":"\uc7a0\uc2e42\ub3d9","household":"11,964","pop_total_male":"17,569","pop_total_female":"19,143","over_65":"3,326"},{"gu":"\uc1a1\ud30c\uad6c","dong":"\uc7a0\uc2e43\ub3d9","household":"12,176","pop_total_male":"17,048","pop_total_female":"18,732","over_65":"5,254"},{"gu":"\uc1a1\ud30c\uad6c","dong":"\uc7a5\uc9c0\ub3d9","household":"12,268","pop_total_male":"14,990","pop_total_female":"16,032","over_65":"4,094"},{"gu":"\uc1a1\ud30c\uad6c","dong":"\uc704\ub840\ub3d9","household":"9,030","pop_total_male":"13,763","pop_total_female":"14,581","over_65":"2,013"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uac15\uc77c\ub3d9","household":"11,253","pop_total_male":"15,383","pop_total_female":"16,483","over_65":"4,686"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uc0c1\uc77c\ub3d9","household":"11,349","pop_total_male":"16,137","pop_total_female":"16,487","over_65":"3,473"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uba85\uc77c1\ub3d9","household":"10,037","pop_total_male":"12,976","pop_total_female":"13,574","over_65":"3,732"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uba85\uc77c2\ub3d9","household":"5,981","pop_total_male":"8,625","pop_total_female":"8,876","over_65":"2,372"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uace0\ub3551\ub3d9","household":"8,938","pop_total_male":"13,494","pop_total_female":"13,042","over_65":"2,732"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uace0\ub3552\ub3d9","household":"8,146","pop_total_male":"10,829","pop_total_female":"10,477","over_65":"2,619"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uc554\uc0ac2\ub3d9","household":"6,382","pop_total_male":"7,583","pop_total_female":"8,064","over_65":"2,285"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uc554\uc0ac3\ub3d9","household":"6,352","pop_total_male":"9,006","pop_total_female":"9,432","over_65":"2,456"},{"gu":"\uac15\ub3d9\uad6c","dong":"\ucc9c\ud6381\ub3d9","household":"12,862","pop_total_male":"13,782","pop_total_female":"14,259","over_65":"4,930"},{"gu":"\uac15\ub3d9\uad6c","dong":"\ucc9c\ud6383\ub3d9","household":"13,759","pop_total_male":"13,370","pop_total_female":"13,933","over_65":"4,501"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uc131\ub0b41\ub3d9","household":"8,169","pop_total_male":"9,869","pop_total_female":"10,534","over_65":"2,900"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uc131\ub0b42\ub3d9","household":"12,759","pop_total_male":"12,344","pop_total_female":"12,752","over_65":"4,139"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uc131\ub0b43\ub3d9","household":"10,498","pop_total_male":"11,713","pop_total_female":"12,111","over_65":"3,594"},{"gu":"\uac15\ub3d9\uad6c","dong":"\ub454\ucd0c1\ub3d9","household":"161","pop_total_male":"130","pop_total_female":"144","over_65":"96"},{"gu":"\uac15\ub3d9\uad6c","dong":"\ub454\ucd0c2\ub3d9","household":"11,234","pop_total_male":"13,475","pop_total_female":"13,817","over_65":"4,111"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uc554\uc0ac1\ub3d9","household":"16,179","pop_total_male":"17,927","pop_total_female":"18,327","over_65":"5,796"},{"gu":"\uac15\ub3d9\uad6c","dong":"\ucc9c\ud6382\ub3d9","household":"17,754","pop_total_male":"17,696","pop_total_female":"17,946","over_65":"5,875"},{"gu":"\uac15\ub3d9\uad6c","dong":"\uae38\ub3d9","household":"21,282","pop_total_male":"22,903","pop_total_female":"24,047","over_65":"7,445"}]

gu_population = {}  
for item in data:   #구와 구의 인구수를 딕셔너리로 엮기
    gu_population[item["gu"]] = gu_population.get(item['gu'],0) + int( "".join(item["pop_total_male"].split(",")) ) + int( "".join(item["pop_total_female"].split(",")) )   #키 값을 구 이름으로 놓고, 밸유값에는 인구를 누적시킨다.

region_list = list(gu_population.keys())
print(region_list)
# Out:
# ['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구']

# %%
#치과
#url 바꿔가면서 찾기
hospital_number = {}
hospital_review_number_mean = {}
population_per_hospital = {}

for region in region_list:
    url = f"https://www.modoodoc.com/q/?search_query={region}%20치과"
    driver = webdriver.Chrome('./chromedriver/chromedriver.exe')
    driver.implicitly_wait(2)
    driver.get(url)
    search_result = int(driver.find_element_by_class_name('color49').text[5:-1])
    hospital_number[region] = search_result
    
    req = requests.get(url)   #리뷰수
    html = req.text
    soup = BeautifulSoup(html, "html.parser")
    review_list = soup.find_all(attrs={'class':"review-count-box ml-1"})
    striped_list = [(i.text).strip() for i in review_list]
    review_number_list = [int(j[8:-1]) for j in striped_list]
    number_mean = sum(review_number_list) / len(review_number_list)
    hospital_review_number_mean[region] = number_mean
    
    driver.quit()  # 창 닫기
    
for item in region_list:    # 인구비율
    population_per_hospital[item] = gu_population[item]//hospital_number[item]

    
# 일단 진료과목별로 저장해 두기
dental_number = hospital_number
dental_review = hospital_review_number_mean
dental_population = population_per_hospital

#출력

dental_data_all = { "지역구":region_list, "치과 수": list(hospital_number.values()) , "치과 하나당 인구수":list(population_per_hospital.values()) ,"상위권 리뷰수":list(hospital_review_number_mean.values())}

dental_data = pd.DataFrame(dental_data_all)
dental_data
# Out:
#      지역구  치과 수  치과 하나당 인구수  상위권 리뷰수
# 0    종로구   195         823    17.95
# 1     중구   707         192    17.65
# 2    용산구    96        2555     9.15
# 3    성동구   156        1954    11.40
# 4    광진구   194        1875    16.00
# 5   동대문구   179        2013    15.95
# 6    중랑구   165        2420    10.35
# 7    성북구   163        2774    15.15
# 8    강북구   151        2088    14.55
# 9    도봉구   129        2571     7.55
# 10   노원구   227        2348    14.45
# 11   은평구   209        2315    12.55
# 12  서대문구   156        2078    25.10
# 13   마포구   235        1638    26.95
# 14   양천구   233        1982    13.50
# 15   강서구   325        1825    14.15
# 16   구로구   175        2495    12.80
# 17   금천구   120        2087     9.00
# 18  영등포구   278        1457    16.35
# 19   동작구   226        1799    17.40
# 20   관악구   251        2057    44.90
# 21   서초구   521         831    23.50
# 22   강남구   804         679    25.50
# 23   송파구   391        1734    21.55
# 24   강동구   282        1636    10.05

# %%
#피부과
#url 바꿔가면서 찾기
hospital_number = {}
hospital_review_number_mean = {}
population_per_hospital = {}

for region in region_list:
    url = f"https://www.modoodoc.com/q/?search_query={region}%20피부과"
    driver = webdriver.Chrome('./chromedriver/chromedriver.exe')
    driver.implicitly_wait(2)
    driver.get(url)
    search_result = int(driver.find_element_by_class_name('color49').text[5:-1])
    hospital_number[region] = search_result
    
    req = requests.get(url)   #리뷰수
    html = req.text
    soup = BeautifulSoup(html, "html.parser")
    review_list = soup.find_all(attrs={'class':"review-count-box ml-1"})
    striped_list = [(i.text).strip() for i in review_list]
    review_number_list = [int(j[8:-1]) for j in striped_list]
    number_mean = sum(review_number_list) / len(review_number_list)
    hospital_review_number_mean[region] = number_mean
    
    driver.quit()  # 창 닫기
    
for item in region_list:    # 인구비율
    population_per_hospital[item] = gu_population[item]//hospital_number[item]

    
    
# 일단 진료과목별로 저장해 두기
dermatic_number = hospital_number
dermatic_review = hospital_review_number_mean
dermatic_population = population_per_hospital

# 출력

dermatic_data_all = { "지역구":region_list, "피부과 수": list(hospital_number.values()) , "피부과 하나당 인구수":list(population_per_hospital.values()),"상위권 리뷰수":list(hospital_review_number_mean.values()) }

dermatic_data = pd.DataFrame(dermatic_data_all)
dermatic_data
# Out:
#      지역구  피부과 수  피부과 하나당 인구수  상위권 리뷰수
# 0    종로구     47         3415    17.15
# 1     중구    169          804    23.15
# 2    용산구     45         5452    10.75
# 3    성동구     35         8710    19.60
# 4    광진구     62         5869    22.50
# 5   동대문구     31        11625    15.65
# 6    중랑구     46         8682    12.95
# 7    성북구     52         8697    12.55
# 8    강북구     42         7509    12.15
# 9    도봉구     21        15797     7.25
# 10   노원구     67         7955    22.20
# 11   은평구     57         8490    18.25
# 12  서대문구     54         6004    20.45
# 13   마포구    130         2961    38.55
# 14   양천구     55         8400    17.45
# 15   강서구     93         6378    24.90
# 16   구로구     62         7043    22.25
# 17   금천구     21        11931     8.55
# 18  영등포구     69         5871    21.70
# 19   동작구     57         7136    22.15
# 20   관악구     62         8327    28.00
# 21   서초구    253         1711    47.80
# 22   강남구    779          701    58.90
# 23   송파구    123         5512    25.95
# ...

# %%
#안과
#url 바꿔가면서 찾기
hospital_number = {}
hospital_review_number_mean = {}
population_per_hospital = {}

for region in region_list:
    url = f"https://www.modoodoc.com/q/?search_query={region}%20안과"
    driver = webdriver.Chrome('./chromedriver/chromedriver.exe')
    driver.implicitly_wait(2)
    driver.get(url)
    search_result = int(driver.find_element_by_class_name('color49').text[5:-1])
    hospital_number[region] = search_result
    
    req = requests.get(url)   #리뷰수
    html = req.text
    soup = BeautifulSoup(html, "html.parser")
    review_list = soup.find_all(attrs={'class':"review-count-box ml-1"})
    striped_list = [(i.text).strip() for i in review_list]
    review_number_list = [int(j[8:-1]) for j in striped_list]
    number_mean = sum(review_number_list) / len(review_number_list)
    hospital_review_number_mean[region] = number_mean
    
    driver.quit()  # 창 닫기
    
for item in region_list:    # 인구비율
    population_per_hospital[item] = gu_population[item]//hospital_number[item]

    
# 일단 진료과목별로 저장해 두기
ophthalmic_number = hospital_number
ophthalmic_review = hospital_review_number_mean
ophthalmic_population = population_per_hospital

# 출력

ophthalmic_data_all = { "지역구":region_list, "안과 수": list(hospital_number.values()) , "안과 하나당 인구수":list(population_per_hospital.values()) ,"상위권 리뷰수":list(hospital_review_number_mean.values())}

ophthalmic_data = pd.DataFrame(ophthalmic_data_all)
ophthalmic_data
# Out:
#      지역구  안과 수  안과 하나당 인구수    상위권 리뷰수
# 0    종로구    23        6979  14.450000
# 1     중구   113        1203  10.500000
# 2    용산구    14       17525   8.214286
# 3    성동구    15       20323  12.600000
# 4    광진구    16       22745  14.312500
# 5   동대문구    18       20021   7.777778
# 6    중랑구    14       28529  11.642857
# 7    성북구    21       21537  10.450000
# 8    강북구    22       14336   8.400000
# 9    도봉구    15       22116   6.666667
# 10   노원구    41       13001  11.700000
# 11   은평구    23       21040  10.750000
# 12  서대문구    16       20264  14.187500
# 13   마포구    21       18331  18.400000
# 14   양천구    16       28877  12.625000
# 15   강서구    49       12106  13.150000
# 16   구로구    21       20795  10.850000
# 17   금천구    10       25055  16.800000
# 18  영등포구    88        4604  10.850000
# 19   동작구    17       23928  13.764706
# 20   관악구    25       20652  15.600000
# 21   서초구   102        4245  21.050000
# 22   강남구   177        3085  19.600000
# 23   송파구    48       14126  16.050000
# ...

# %%
#성형외과
#url 바꿔가면서 찾기
hospital_number = {}
hospital_review_number_mean = {}
population_per_hospital = {}

for region in region_list:
    url = f"https://www.modoodoc.com/q/?search_query={region}%20성형외과"
    driver = webdriver.Chrome('./chromedriver/chromedriver.exe')
    driver.implicitly_wait(2)
    driver.get(url)
    search_result = int(driver.find_element_by_class_name('color49').text[5:-1])
    hospital_number[region] = search_result
    
    req = requests.get(url)
    html = req.text
    soup = BeautifulSoup(html, "html.parser")
    review_list = soup.find_all(attrs={'class':"review-count-box ml-1"})
    striped_list = [(i.text).strip() for i in review_list]
    review_number_list = [int(j[8:-1]) for j in striped_list]
    number_mean = sum(review_number_list) / len(review_number_list)
    hospital_review_number_mean[region] = number_mean
    
    driver.quit()  # 창 닫기
    
for item in region_list:    
    population_per_hospital[item] = gu_population[item]//hospital_number[item]

    
# 일단 진료과목별로 저장해 두기
cosmetic_number = hospital_number
cosmetic_review = hospital_review_number_mean
cosmetic_population = population_per_hospital

# 출력

cosmetic_data_all = { "지역구":region_list, "성형외과 수": list(hospital_number.values()) , "성형외과 하나당 인구수":list(population_per_hospital.values()) ,"상위권 리뷰수":list(hospital_review_number_mean.values())}

cosmetic_data = pd.DataFrame(cosmetic_data_all)
cosmetic_data
# Out:
#      지역구  성형외과 수  성형외과 하나당 인구수    상위권 리뷰수
# 0    종로구       5         32104   2.200000
# 1     중구     131          1038   1.950000
# 2    용산구       3         81787   3.000000
# 3    성동구       5         60970   3.200000
# 4    광진구       8         45490   2.125000
# 5   동대문구       9         40042   1.000000
# 6    중랑구       3        133138   0.000000
# 7    성북구       4        113072   0.750000
# 8    강북구       7         45056   1.571429
# 9    도봉구       2        165872   0.000000
# 10   노원구      17         31355   0.705882
# 11   은평구       7         69134   0.428571
# 12  서대문구       7         46317   3.714286
# 13   마포구      18         21386   5.111111
# 14   양천구       8         57754   0.375000
# 15   강서구      16         37075   1.562500
# 16   구로구       4        109176   0.750000
# 17   금천구       1        250554   0.000000
# 18  영등포구      11         36832   4.000000
# 19   동작구       5         81355   1.000000
# 20   관악구      13         39716   0.769231
# ...

# %%
#내과
#url 바꿔가면서 찾기
hospital_number = {}
hospital_review_number_mean = {}
population_per_hospital = {}

for region in region_list:
    url = f"https://www.modoodoc.com/q/?search_query={region}%20내과"
    driver = webdriver.Chrome('./chromedriver/chromedriver.exe')
    driver.implicitly_wait(2)
    driver.get(url)
    search_result = int(driver.find_element_by_class_name('color49').text[5:-1])
    hospital_number[region] = search_result
    
    req = requests.get(url)
    html = req.text
    soup = BeautifulSoup(html, "html.parser")
    review_list = soup.find_all(attrs={'class':"review-count-box ml-1"})
    striped_list = [(i.text).strip() for i in review_list]
    review_number_list = [int(j[8:-1]) for j in striped_list]
    number_mean = sum(review_number_list) / len(review_number_list)
    hospital_review_number_mean[region] = number_mean
    
    driver.quit()  # 창 닫기
    
for item in region_list:   
    population_per_hospital[item] = gu_population[item]//hospital_number[item]

    
# 일단 진료과목별로 저장해 두기
internel_number = hospital_number
internel_review = hospital_review_number_mean
internel_population = population_per_hospital

# 출력

internel_data_all = { "지역구":region_list, "내과 수": list(hospital_number.values()) , "내과 하나당 인구수":list(population_per_hospital.values()) ,"상위권 리뷰수":list(hospital_review_number_mean.values())}

internel_data = pd.DataFrame(internel_data_all)
internel_data
# Out:
#      지역구  내과 수  내과 하나당 인구수  상위권 리뷰수
# 0    종로구    44        3648     6.55
# 1     중구   358         379     7.25
# 2    용산구    60        4089     4.65
# 3    성동구    63        4838     5.70
# 4    광진구    78        4665     7.65
# 5   동대문구    89        4049     4.90
# 6    중랑구    88        4538     4.10
# 7    성북구    95        4760     6.20
# 8    강북구   104        3032     2.90
# 9    도봉구    61        5438     3.20
# 10   노원구    96        5552     4.85
# 11   은평구   107        4522     5.50
# 12  서대문구    50        6484     5.35
# 13   마포구   114        3376     9.65
# 14   양천구    82        5634     7.10
# 15   강서구   162        3661     5.85
# 16   구로구    99        4411     6.30
# 17   금천구    63        3977     4.90
# 18  영등포구   109        3717     8.60
# 19   동작구    82        4960     7.15
# 20   관악구    84        6146    10.10
# 21   서초구   127        3409     6.70
# 22   강남구   292        1870    10.15
# 23   송파구   169        4012    13.25
# 24   강동구   124        3722     5.00

# %%
#소아과
#url 바꿔가면서 찾기
hospital_number = {}
hospital_review_number_mean = {}
population_per_hospital = {}

for region in region_list:
    url = f"https://www.modoodoc.com/q/?search_query={region}%20소아과"
    driver = webdriver.Chrome('./chromedriver/chromedriver.exe')
    driver.implicitly_wait(2)
    driver.get(url)
    search_result = int(driver.find_element_by_class_name('color49').text[5:-1])
    hospital_number[region] = search_result
    
    req = requests.get(url)
    html = req.text
    soup = BeautifulSoup(html, "html.parser")
    review_list = soup.find_all(attrs={'class':"review-count-box ml-1"})
    striped_list = [(i.text).strip() for i in review_list]
    review_number_list = [int(j[8:-1]) for j in striped_list]
    number_mean = sum(review_number_list) / len(review_number_list)
    hospital_review_number_mean[region] = number_mean
    
    driver.quit()  # 창 닫기
    
for item in region_list:    
    population_per_hospital[item] = gu_population[item]//hospital_number[item]

    
# 일단 진료과목별로 저장해 두기
pediatric_number = hospital_number
pediatric_review = hospital_review_number_mean
pediatric_population = population_per_hospital

# 출력

pediatric_data_all = { "지역구":region_list, "소아과 수": list(hospital_number.values()) , "소아과 하나당 인구수":list(population_per_hospital.values()) ,"상위권 리뷰수":list(hospital_review_number_mean.values())}

pediatric_data = pd.DataFrame(pediatric_data_all)
pediatric_data
# Out:
#      지역구  소아과 수  소아과 하나당 인구수   상위권 리뷰수
# 0    종로구      5        32104  2.600000
# 1     중구     46         2957  1.550000
# 2    용산구     29         8460  1.200000
# 3    성동구     32         9526  2.250000
# 4    광진구     35        10397  2.850000
# 5   동대문구     34        10599  2.550000
# 6    중랑구     37        10795  3.150000
# 7    성북구     38        11902  1.900000
# 8    강북구     30        10513  1.100000
# 9    도봉구     28        11848  1.700000
# 10   노원구     47        11341  2.950000
# 11   은평구     36        13442  3.300000
# 12  서대문구     19        17064  1.157895
# 13   마포구     37        10404  2.400000
# 14   양천구     33        14001  4.500000
# 15   강서구     71         8354  4.850000
# 16   구로구     55         7940  3.000000
# 17   금천구     19        13187  1.421053
# 18  영등포구     36        11254  4.000000
# 19   동작구     32        12711  2.500000
# 20   관악구     36        14342  2.650000
# 21   서초구     48         9022  1.850000
# 22   강남구     58         9416  2.400000
# ...

# %%
#정형외과
#url 바꿔가면서 찾기
hospital_number = {}
hospital_review_number_mean = {}
population_per_hospital = {}

for region in region_list:
    url = f"https://www.modoodoc.com/q/?search_query={region}%20정형외과"
    driver = webdriver.Chrome('./chromedriver/chromedriver.exe')
    driver.implicitly_wait(2)
    driver.get(url)
    search_result = int(driver.find_element_by_class_name('color49').text[5:-1])
    hospital_number[region] = search_result
    
    req = requests.get(url)
    html = req.text
    soup = BeautifulSoup(html, "html.parser")
    review_list = soup.find_all(attrs={'class':"review-count-box ml-1"})
    striped_list = [(i.text).strip() for i in review_list]
    review_number_list = [int(j[8:-1]) for j in striped_list]
    number_mean = sum(review_number_list) / len(review_number_list)
    hospital_review_number_mean[region] = number_mean
    
    driver.quit()  # 창 닫기
    
for item in region_list:    
    population_per_hospital[item] = gu_population[item]//hospital_number[item]

    
# 일단 진료과목별로 저장해 두기
orthopedic_number = hospital_number
orthopedic_review = hospital_review_number_mean
orthopedic_population = population_per_hospital

# 출력

orthopedic_data_all = { "지역구":region_list, "정형외과 수": list(hospital_number.values()) , "정형외과 하나당 인구수":list(population_per_hospital.values()) ,"상위권 리뷰수":list(hospital_review_number_mean.values())}

orthopedic_data = pd.DataFrame(orthopedic_data_all)
orthopedic_data
# Out:
#      지역구  정형외과 수  정형외과 하나당 인구수  상위권 리뷰수
# 0    종로구      23          6979    10.45
# 1     중구     122          1115    11.60
# 2    용산구      21         11683     8.40
# 3    성동구      40          7621     9.65
# 4    광진구      43          8463     7.95
# 5   동대문구      55          6552     8.25
# 6    중랑구      66          6051     7.95
# 7    성북구      47          9623     8.05
# 8    강북구      45          7008     9.55
# 9    도봉구      41          8091     5.15
# 10   노원구      64          8328     9.90
# 11   은평구      63          7681    10.90
# 12  서대문구      22         14737     5.70
# 13   마포구      55          6999    21.75
# 14   양천구      59          7831    10.25
# 15   강서구      92          6447    13.60
# 16   구로구      48          9098     6.55
# 17   금천구      39          6424     6.10
# 18  영등포구      56          7234    13.65
# 19   동작구      38         10704    12.20
# 20   관악구      64          8067    20.10
# 21   서초구     106          4085    13.80
# ...

# %%
#정신건강의학과
#url 바꿔가면서 찾기
hospital_number = {}
hospital_review_number_mean = {}
population_per_hospital = {}

for region in region_list:
    url = f"https://www.modoodoc.com/q/?search_query={region}%20정신건강의학과"
    driver = webdriver.Chrome('./chromedriver/chromedriver.exe')
    driver.implicitly_wait(2)
    driver.get(url)
    search_result = int(driver.find_element_by_class_name('color49').text[5:-1])
    hospital_number[region] = search_result
    
    req = requests.get(url)
    html = req.text
    soup = BeautifulSoup(html, "html.parser")
    review_list = soup.find_all(attrs={'class':"review-count-box ml-1"})
    striped_list = [(i.text).strip() for i in review_list]
    review_number_list = [int(j[8:-1]) for j in striped_list]
    number_mean = sum(review_number_list) / len(review_number_list)
    hospital_review_number_mean[region] = number_mean
    
    driver.quit()  # 창 닫기
    
for item in region_list:    
    population_per_hospital[item] = gu_population[item]//hospital_number[item]

    
# 일단 진료과목별로 저장해 두기
psych_number = hospital_number
psych_review = hospital_review_number_mean
psych_population = population_per_hospital

# 출력

psych_data_all = { "지역구":region_list, "정신건강의학과 수": list(hospital_number.values()) , "정신건강의학과 하나당 인구수":list(population_per_hospital.values()) ,"상위권 리뷰수":list(hospital_review_number_mean.values())}

psych_data = pd.DataFrame(psych_data_all)
psych_data
# Out:
#      지역구  정신건강의학과 수  정신건강의학과 하나당 인구수   상위권 리뷰수
# 0    종로구         33             4864  3.950000
# 1     중구         50             2720  2.200000
# 2    용산구          4            61340  5.000000
# 3    성동구         10            30485  3.700000
# 4    광진구         63             5776  2.850000
# 5   동대문구         24            15015  2.100000
# 6    중랑구         14            28529  1.500000
# 7    성북구         15            30152  2.133333
# 8    강북구         11            28672  4.181818
# 9    도봉구         16            20734  0.562500
# 10   노원구         21            25382  2.750000
# 11   은평구         28            17283  2.300000
# 12  서대문구         10            32422  2.900000
# 13   마포구         28            13748  5.250000
# 14   양천구         13            35541  1.692308
# 15   강서구         26            22815  3.300000
# 16   구로구         22            19850  4.150000
# 17   금천구         16            15659  1.125000
# 18  영등포구         18            22508  2.611111
# ...

# %%
all_hospital_numbers = {"지역구": region_list, "치과 수": list(dental_number.values()), "피부과 수": list(dermatic_number.values()), "안과 수": list(ophthalmic_number.values()), "성형외과 수": list(cosmetic_number.values()), "내과 수": list(internel_number.values()), "소아과 수": list(pediatric_number.values()), "정형외과 수": list(orthopedic_number.values()), "정신건강의학과 수": list(psych_number.values())}
hospital_numbers_df = pd.DataFrame(all_hospital_numbers)
hospital_numbers_df
# Out:
#      지역구  치과 수  피부과 수  안과 수  성형외과 수  내과 수  소아과 수  정형외과 수  정신건강의학과 수
# 0    종로구   195     47    23       5    44      5      23         33
# 1     중구   707    169   113     131   358     46     122         50
# 2    용산구    96     45    14       3    60     29      21          4
# 3    성동구   156     35    15       5    63     32      40         10
# 4    광진구   194     62    16       8    78     35      43         63
# 5   동대문구   179     31    18       9    89     34      55         24
# 6    중랑구   165     46    14       3    88     37      66         14
# 7    성북구   163     52    21       4    95     38      47         15
# 8    강북구   151     42    22       7   104     30      45         11
# 9    도봉구   129     21    15       2    61     28      41         16
# 10   노원구   227     67    41      17    96     47      64         21
# 11   은평구   209     57    23       7   107     36      63         28
# 12  서대문구   156     54    16       7    50     19      22         10
# ...
